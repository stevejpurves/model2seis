# %% [markdown]
# All of the pynoddy examples

# %%
# %matplotlib inline

# %%
import sys, os
import matplotlib.pyplot as plt
import numpy as np
# adjust some settings for matplotlib
from matplotlib import rcParams
# print rcParams
rcParams['font.size'] = 15
# determine path of repository to set paths corretly below
repo_path = os.path.realpath('../..')
import pynoddy
import pynoddy.history
import pynoddy.output

# %%
def computeAndDisplaySection(history_file, output_name, cube_size):
    # We will first recompute the model and store results in an output file for comparison
    NH1 = pynoddy.history.NoddyHistory(history_file)
    NH1.change_cube_size(cube_size)
    NH1.write_history(history_file+'.mod')
    pynoddy.compute_model(history_file+'.mod', output_name)
    NO1 = pynoddy.output.NoddyOutput(output_name)
    # create basic figure layout
    fig = plt.figure(figsize = (15,5))
    NO1.plot_section('y', position=10, colorbar=True, title=output_name)
    plt.show()

# %%
computeAndDisplaySection('simple_two_faults.his','simple_two_faults', 40)

# %%
computeAndDisplaySection('slightly_complicated.his','slightly_complicated', 50)

# %%
computeAndDisplaySection('two_faults_fold_unconformity_slice.his','two_faults_fold_unconformity_slice',50)

# %%
computeAndDisplaySection('fold_dyke_fault.his','fold_dyke_fault',50)

# %%
computeAndDisplaySection('GBasi123.his','GBasi123',50)

# %%
computeAndDisplaySection('GBasin_simplified.his','GBasin_simplified',50)

# %%
computeAndDisplaySection('GBasin_Ve1_V4.his','GBasin_Ve1_V4',50)

# %%
computeAndDisplaySection('GBasin_Ve1_V4_b.his','GBasin_Ve1_V4_b',50)

# %%
computeAndDisplaySection('GBasin_Ve1_V4_ve10.his','GBasin_Ve1_V4_ve10',50)

# %%
computeAndDisplaySection('GBasin_Ve1_V5.his','GBasin_Ve1_V5',50)
