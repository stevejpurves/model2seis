# %%
# %matplotlib inline
import sys, os
import matplotlib.pyplot as plt
import numpy as np
# adjust some settings for matplotlib
from matplotlib import rcParams
# print rcParams
rcParams['font.size'] = 15
# determine path of repository to set paths corretly below
repo_path = os.path.realpath('../..')
import pynoddy
import pynoddy.history
import pynoddy.output
import pynoddy.experiment.uncertainty_analysis

# %%
cube_size = 25
model_name = 'fold_dyke_fault'
block_shape = (5000,10000,7000)
model_path = 'models_'+model_name
num_realisations = 100

# %%
history_file = model_name+'.his'
NH1 = pynoddy.history.NoddyHistory(history_file)
NH1.change_cube_size(cube_size)
NH1.write_history(history_file+'.mod')

ua = pynoddy.experiment.uncertainty_analysis.UncertaintyAnalysis(model_name+'.his.mod', model_name+'.csv')
ua.estimate_uncertainty(num_realisations,verbose=True, model_path=model_path, cleanup=False)
# Out:
# Producing model realisations...
# Constructing out_0001...
# Changing Dip to 45.2316617036
# Changing Dip Direction to 88.2466725675
# Changing Slip to 1865.38488899
# Changing Dip to 93.8037796558
# Changing Dip Direction to 136.817618975
# Complete.
# Running out_0001...
#
# Complete.
# Loading models...
# Loading models in models_fold_dyke_fault
# Loading models_fold_dyke_fault/out_0001
# Loading models_fold_dyke_fault/out_0002

# %%
import os
from utils import *

# cube_size = 25
# model_name = 'fold_dyke_fault'
# block_shape = (5000,10000,7000)
# num_realisations = 10
output_path = 'data_'+model_name

if not os.path.exists(output_path):
    os.makedirs(output_path)
    
output_filename_stub = output_path+'/'
print output_filename_stub

for n in range(0,num_realisations):
    label = '{0:04d}'.format(n+1) 
    
    block_file_name = model_path+'/out_'+label
    print("loading...", block_file_name)
    model = loadBlock(block_file_name, block_shape, cube_size)
    
    outfile = output_filename_stub+'out_'+label+'_'
    print("writing to...", output_filename_stub+'out_'+label+'_')
    extractSlicesFromBlock(model, (25,25), outfile)
# Out:
# data_fold_dyke_fault/
# ('loading...', 'models_fold_dyke_fault/out_0001')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0001_')
# ('loading...', 'models_fold_dyke_fault/out_0002')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0002_')
# ('loading...', 'models_fold_dyke_fault/out_0003')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0003_')
# ('loading...', 'models_fold_dyke_fault/out_0004')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0004_')
# ('loading...', 'models_fold_dyke_fault/out_0005')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0005_')
# ('loading...', 'models_fold_dyke_fault/out_0006')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0006_')
# ('loading...', 'models_fold_dyke_fault/out_0007')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0007_')
# ('loading...', 'models_fold_dyke_fault/out_0008')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0008_')
# ('loading...', 'models_fold_dyke_fault/out_0009')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0009_')
# ('loading...', 'models_fold_dyke_fault/out_0010')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0010_')
# ('loading...', 'models_fold_dyke_fault/out_0011')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0011_')
# ('loading...', 'models_fold_dyke_fault/out_0012')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0012_')
# ('loading...', 'models_fold_dyke_fault/out_0013')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0013_')
# ('loading...', 'models_fold_dyke_fault/out_0014')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0014_')
# ('loading...', 'models_fold_dyke_fault/out_0015')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0015_')
# ('loading...', 'models_fold_dyke_fault/out_0016')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0016_')
# ('loading...', 'models_fold_dyke_fault/out_0017')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0017_')
# ('loading...', 'models_fold_dyke_fault/out_0018')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0018_')
# ('loading...', 'models_fold_dyke_fault/out_0019')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0019_')
# ('loading...', 'models_fold_dyke_fault/out_0020')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0020_')
# ('loading...', 'models_fold_dyke_fault/out_0021')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0021_')
# ('loading...', 'models_fold_dyke_fault/out_0022')
# /Users/stevejpurves/anaconda3/envs/python2/lib/python2.7/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0022_')
# ('loading...', 'models_fold_dyke_fault/out_0023')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0023_')
# ('loading...', 'models_fold_dyke_fault/out_0024')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0024_')
# ('loading...', 'models_fold_dyke_fault/out_0025')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0025_')
# ('loading...', 'models_fold_dyke_fault/out_0026')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0026_')
# ('loading...', 'models_fold_dyke_fault/out_0027')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0027_')
# ('loading...', 'models_fold_dyke_fault/out_0028')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0028_')
# ('loading...', 'models_fold_dyke_fault/out_0029')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0029_')
# ('loading...', 'models_fold_dyke_fault/out_0030')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0030_')
# ('loading...', 'models_fold_dyke_fault/out_0031')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0031_')
# ('loading...', 'models_fold_dyke_fault/out_0032')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0032_')
# ('loading...', 'models_fold_dyke_fault/out_0033')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0033_')
# ('loading...', 'models_fold_dyke_fault/out_0034')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0034_')
# ('loading...', 'models_fold_dyke_fault/out_0035')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0035_')
# ('loading...', 'models_fold_dyke_fault/out_0036')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0036_')
# ('loading...', 'models_fold_dyke_fault/out_0037')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0037_')
# ('loading...', 'models_fold_dyke_fault/out_0038')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0038_')
# ('loading...', 'models_fold_dyke_fault/out_0039')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0039_')
# ('loading...', 'models_fold_dyke_fault/out_0040')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0040_')
# ('loading...', 'models_fold_dyke_fault/out_0041')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0041_')
# ('loading...', 'models_fold_dyke_fault/out_0042')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0042_')
# ('loading...', 'models_fold_dyke_fault/out_0043')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0043_')
# ('loading...', 'models_fold_dyke_fault/out_0044')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0044_')
# ('loading...', 'models_fold_dyke_fault/out_0045')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0045_')
# ('loading...', 'models_fold_dyke_fault/out_0046')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0046_')
# ('loading...', 'models_fold_dyke_fault/out_0047')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0047_')
# ('loading...', 'models_fold_dyke_fault/out_0048')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0048_')
# ('loading...', 'models_fold_dyke_fault/out_0049')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0049_')
# ('loading...', 'models_fold_dyke_fault/out_0050')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0050_')
# ('loading...', 'models_fold_dyke_fault/out_0051')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0051_')
# ('loading...', 'models_fold_dyke_fault/out_0052')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0052_')
# ('loading...', 'models_fold_dyke_fault/out_0053')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0053_')
# ('loading...', 'models_fold_dyke_fault/out_0054')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0054_')
# ('loading...', 'models_fold_dyke_fault/out_0055')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0055_')
# ('loading...', 'models_fold_dyke_fault/out_0056')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0056_')
# ('loading...', 'models_fold_dyke_fault/out_0057')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0057_')
# ('loading...', 'models_fold_dyke_fault/out_0058')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0058_')
# ('loading...', 'models_fold_dyke_fault/out_0059')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0059_')
# ('loading...', 'models_fold_dyke_fault/out_0060')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0060_')
# ('loading...', 'models_fold_dyke_fault/out_0061')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0061_')
# ('loading...', 'models_fold_dyke_fault/out_0062')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0062_')
# ('loading...', 'models_fold_dyke_fault/out_0063')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0063_')
# ('loading...', 'models_fold_dyke_fault/out_0064')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0064_')
# ('loading...', 'models_fold_dyke_fault/out_0065')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0065_')
# ('loading...', 'models_fold_dyke_fault/out_0066')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0066_')
# ('loading...', 'models_fold_dyke_fault/out_0067')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0067_')
# ('loading...', 'models_fold_dyke_fault/out_0068')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0068_')
# ('loading...', 'models_fold_dyke_fault/out_0069')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0069_')
# ('loading...', 'models_fold_dyke_fault/out_0070')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0070_')
# ('loading...', 'models_fold_dyke_fault/out_0071')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0071_')
# ('loading...', 'models_fold_dyke_fault/out_0072')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0072_')
# ('loading...', 'models_fold_dyke_fault/out_0073')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0073_')
# ('loading...', 'models_fold_dyke_fault/out_0074')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0074_')
# ('loading...', 'models_fold_dyke_fault/out_0075')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0075_')
# ('loading...', 'models_fold_dyke_fault/out_0076')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0076_')
# ('loading...', 'models_fold_dyke_fault/out_0077')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0077_')
# ('loading...', 'models_fold_dyke_fault/out_0078')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0078_')
# ('loading...', 'models_fold_dyke_fault/out_0079')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0079_')
# ('loading...', 'models_fold_dyke_fault/out_0080')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0080_')
# ('loading...', 'models_fold_dyke_fault/out_0081')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0081_')
# ('loading...', 'models_fold_dyke_fault/out_0082')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0082_')
# ('loading...', 'models_fold_dyke_fault/out_0083')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0083_')
# ('loading...', 'models_fold_dyke_fault/out_0084')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0084_')
# ('loading...', 'models_fold_dyke_fault/out_0085')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0085_')
# ('loading...', 'models_fold_dyke_fault/out_0086')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0086_')
# ('loading...', 'models_fold_dyke_fault/out_0087')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0087_')
# ('loading...', 'models_fold_dyke_fault/out_0088')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0088_')
# ('loading...', 'models_fold_dyke_fault/out_0089')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0089_')
# ('loading...', 'models_fold_dyke_fault/out_0090')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0090_')
# ('loading...', 'models_fold_dyke_fault/out_0091')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0091_')
# ('loading...', 'models_fold_dyke_fault/out_0092')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0092_')
# ('loading...', 'models_fold_dyke_fault/out_0093')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0093_')
# ('loading...', 'models_fold_dyke_fault/out_0094')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0094_')
# ('loading...', 'models_fold_dyke_fault/out_0095')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0095_')
# ('loading...', 'models_fold_dyke_fault/out_0096')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0096_')
# ('loading...', 'models_fold_dyke_fault/out_0097')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0097_')
# ('loading...', 'models_fold_dyke_fault/out_0098')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0098_')
# ('loading...', 'models_fold_dyke_fault/out_0099')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0099_')
# ('loading...', 'models_fold_dyke_fault/out_0100')
# ('initial model shape', (80000, 280))
# ('target block shape', (5000, 10000, 7000))
# ('writing to...', 'data_fold_dyke_fault/out_0100_')
